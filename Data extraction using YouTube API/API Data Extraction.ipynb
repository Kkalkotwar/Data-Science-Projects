# %%
# Importing Libraries

import pandas as pd
import requests                       # This will help us to import thrh data from the website

# %%
# Importing the API Key and Channel ID

API_KEY = 'AIzaSyBsqFD6BWpJ0dHyoFM_CIL2uLiVVgoWT-o'
channel_id = 'UCNU_lfiiWBdtULKOw6X0Dig'

# %% [markdown]
# # To make an API Call

# %%
pageToken = '10'
url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+channel_id+"&part=snippet,id&order=date&maxResults=10000&"+pageToken
response = requests.get(url).json() # This will get the data from URL & convert it into the JSON format
response                                      # This will give the whike datas
#response['items'][0] # This will give us the details of the very recent video
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'XbOSXJKriUZHlxxPP8rUUrM3fTg',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'IN',
#  'pageInfo': {'totalResults': 1309, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'PL3bFXiBCQqyhuYtugLHeYmJ_nk',
#    'id': {'kind': 'youtube#video', 'videoId': 'W-tE_ZP1zv4'},
#    'snippet': {'publishedAt': '2021-12-15T03:43:19Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'Lifetime Subscription Offer Of OneNeuron Platform Till Jan-15-2022',
#     'description': 'Enroll Now OneNeuron Link: https://one-neuron.ineuron.ai/ Direct call to our Team incase of any queries 8788503778 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/W-tE_ZP1zv4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/W-tE_ZP1zv4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
video_type = response['items'][0]['id']['kind'] # For checking the kind of the video, also ensuring that we are taking the right data, i.e., video
video_type
# Out:
# 'youtube#video'

# %%
# For checking if we are getting the required output or not

video_id = response['items'][0]['id']['videoId']

title = response['items'][0]['snippet']['title']

pub_date = response['items'][0]['snippet']['publishedAt']
pub_date = str(pub_date).split('T')[0]


print('VIDEO_ID: {} \n TITLE: {} \n PUB_DATE: {}'.format(video_id,title,pub_date))
# Out:
# VIDEO_ID: W-tE_ZP1zv4
#  TITLE: Lifetime Subscription Offer Of OneNeuron Platform Till Jan-15-2022
#  PUB_DATE: 2021-12-15

# %% [markdown]
# # Now this above step needs to be done for all the videos, so we need to apply for loop

# %%
# This will give us the Video_ID, Title and Published date of all the videos, starting with the very rescent video on channel

for video in response['items']:
    if video_type == 'youtube#video':
        
        video_id = video['id']['videoId']
        title = video['snippet']['title']
        pub_date = video['snippet']['publishedAt']
        pub_date = str(pub_date).split('T')[0]                # For splitting the date and time and excluding the time and including the date 
        
        
        print(video_id)
        print(title)
        print(pub_date)
# Out:
# W-tE_ZP1zv4
# Lifetime Subscription Offer Of OneNeuron Platform Till Jan-15-2022
# 2021-12-15
# ifGheVyhaQA
# LIVE One Neuron OTT Platform Launch Event
# 2021-12-11
# M-UpXWGxZe4
# OTT Platform For Education OneNeuron- Education As A Service
# 2021-12-11
# gzJGqML4j5k
# Roles And Responsibilities Of An AI Engineer
# 2021-12-07
# FKEJ2_T9swo
# Tutorial on Automated Machine Learning using MLBox
# 2021-12-05
# PUMFSfUQ6FI
# Companies That Has Regular Job Openings For Data Science
# 2021-12-03
# TYaYeLsnljI
# Face Matching Application Using Deep Learning End to End Implementation
# 2021-12-02
# _XjxOPo1LPE
# 3 Ways To Efficiently Increase Your Salary In Data Science Job Switch
# 2021-12-01
# poJ05JtqKZU
# iNeuron Full Stack Data Science Course With Job Guarantee
# 2021-11-25
# DqxG2rme_jI
# The Best Book For Learning &amp; Get Your Basics Strong In Data Science
# 2021-11-23
# 9t56T1wRm7Y
# This Is The Perfect Resume For Data Science Role
# 2021-11-21
# p9U4Gg5uu4M
# ...

# %% [markdown]
# # """Now the above information that we got is related to videos present on the channel, to get the statistics of each video we need to the the second API call, in which we will use the statistics command in the URL to get the respective statistics"""

# %%
# Making the second API call for gathering the statistics

video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
response_stats = requests.get(video_stats_url).json() # This will get the data from URL & convert it into the JSON format
response_stats                                                             # This will give the whike datas
#response_stats['items']
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '3GW4ZU7qhxuO2EGkjgRQcGu6o4c',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'CX84Bc6X4m4WVwOgWH0Kd16zigg',
#    'id': 'YjpxIzvFfpI',
#    'statistics': {'viewCount': '7151',
#     'likeCount': '186',
#     'favoriteCount': '0',
#     'commentCount': '12'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
# This will give us sataistics data of all the videos/ (Here index is 'Zero' to only get the first video statistics data for sample)

view_count = response_stats['items'][0]['statistics']['viewCount']
like_count = response_stats['items'][0]['statistics']['likeCount']
#dislike_count = response_stats['items'][0]['statistics']['dislikeCount']
comment_count = response_stats['items'][0]['statistics']['commentCount']
    
print(view_count)
print(like_count)
#print(dislike_count)
print(comment_count)
# Out:
# 7151
# 186
# 12

# %% [markdown]
# # Now all this above need to be put in the above for loop so that for every iterations the following statistics can be get
#
# # But before that we need to create an empty DataFrame in which we have our features that are 'video_id', 'title', 'pub_date', 'view_count', 'like_count', 'dislike_count', 'comment_count'

# %%
# Creating the empty Data Frame first
df = pd.DataFrame(columns=['Video_ID', 'Title', 'Published_Date', 'View_Count', 'Like_Count', 'Comment_Count'])                                            
df
# Out:
# Empty DataFrame
# Columns: [Video_ID, Title, Published_Date, View_Count, Like_Count, Comment_Count]
# Index: []

# %%
# Now Performing the final for Loop

# %%
# Importing the API Key and Channel ID

API_KEY = 'AIzaSyBsqFD6BWpJ0dHyoFM_CIL2uLiVVgoWT-o' # Assigning the API key
channel_id = 'UCNU_lfiiWBdtULKOw6X0Dig'                              # Assigning the channel ID - Krish Naik (by doing the Ctrl+U on any of the video page)


pageToken = '40'
url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+channel_id+"&part=snippet,id&order=date&maxResults=100000000&"+pageToken 
response = requests.get(url).json() # This will get the data from URL & convert it into the JSON format
#response                                      # This will give the whike datas
#response['items'][0]                    # This will give us the details of the very recent video

video_type = response['items'][0]['id']['kind'] # For checking the kind of the video, also ensuring that we are taking the right data, i.e., video

for video in response['items']:
    if video_type == 'youtube#video':                           # For ensuring that the video which are been accessed are only youtube videos
        video_id = video['id']['videoId']                          # For getting the Video_ID
        title = video['snippet']['title']                             # For getting the titel of video
        pub_date = video['snippet']['publishedAt']         # For getting the published date
        pub_date = str(pub_date).split('T')[0]                # For splitting the date and time and excluding the time and including the date 

        # For having the statistics of the above videos
        # Making the Second API call for Statistics
        
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
        response_stats = requests.get(video_stats_url).json()    # This will get the data from URL & convert it into the JSON format
        #response_stats                                                             # This will give the whike datas
        #response_stats['items']

        view_count = response_stats['items'][0]['statistics']['viewCount']                     # For getting the view count
        like_count = response_stats['items'][0]['statistics']['likeCount']                       # For getting the like count
        #dislike_count = response_stats['items'][0]['statistics']['dislikeCount']           # For getting the dislike counts
        comment_count = response_stats['items'][0]['statistics']['commentCount']     # For getting the comment counts



        #print(video_id)
        #print(title)
        #print(pub_date)
        #print(view_count)
        #print(like_count)
        #print(dislike_count)
        #print(comment_count)

        # Saving file in the pandas data frame:

        df = df.append({'Video_ID':video_id , 'Title':title , 'Published_Date':pub_date, 'View_Count':view_count, 'Like_Count':like_count,'Comment_Count':comment_count}, ignore_index=True)

# %%
df # Calling the data Frame
# Out:
#          Video_ID                                              Title  \
# 0     W-tE_ZP1zv4  Lifetime Subscription Offer Of OneNeuron Platf...
# 1     ifGheVyhaQA          LIVE One Neuron OTT Platform Launch Event
# 2     M-UpXWGxZe4  OTT Platform For Education OneNeuron- Educatio...
# 3     gzJGqML4j5k       Roles And Responsibilities Of An AI Engineer
# 4     FKEJ2_T9swo  Tutorial on Automated Machine Learning using M...
# ...           ...                                                ...
# 1395  Za2tRUQaj3w           Why Many People Are Obsessed With FAANG?
# 1396  6KYJ3QW7CoI  Common Mistakes While Preparing Data Science R...
# 1397  DiOfrCFqs0k  Part 3- Handling Storage permissions in Androi...
# 1398  el_RZOaUhE8  Suggest More Services That We Should Provide I...
# 1399  3GgnzeTT2yc  The Smallest Data Science Resume- Feedback On ...
#
#      Published_Date View_Count Like_Count Comment_Count
# 0        2021-12-15       8937        516           128
# ...

# %%
df.head(60)
# Out:
#        Video_ID                                              Title  \
# 0   W-tE_ZP1zv4  Lifetime Subscription Offer Of OneNeuron Platf...
# 1   ifGheVyhaQA          LIVE One Neuron OTT Platform Launch Event
# 2   M-UpXWGxZe4  OTT Platform For Education OneNeuron- Educatio...
# 3   gzJGqML4j5k       Roles And Responsibilities Of An AI Engineer
# 4   FKEJ2_T9swo  Tutorial on Automated Machine Learning using M...
# 5   PUMFSfUQ6FI  Companies That Has Regular Job Openings For Da...
# 6   TYaYeLsnljI  Face Matching Application Using Deep Learning ...
# 7   _XjxOPo1LPE  3 Ways To Efficiently Increase Your Salary In ...
# 8   poJ05JtqKZU  iNeuron Full Stack Data Science Course With Jo...
# 9   DqxG2rme_jI  The Best Book For Learning &amp; Get Your Basi...
# 10  9t56T1wRm7Y   This Is The Perfect Resume For Data Science Role
# 11  p9U4Gg5uu4M  Skills Based On Experience For Data Science Roles
# 12  MdAxsC0eTpE  Day 3- Final Results Announcement- KIET Hackathon
# ...
